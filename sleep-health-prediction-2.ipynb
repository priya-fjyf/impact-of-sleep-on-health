# %% [markdown]
# # 📘 Sleep and Health Analysis using ML Algorithms
#
# ---
#
# ## 🔍 Dataset Overview
# - Sleep habits, duration, and related health conditions
# - **Target**: Understand how sleep affects overall health
#
# ---
#
# ## 🛠️ Data Preprocessing
# - 🧹 Handling missing values
# - 📊 Encoding categorical variables
# - 📐 Feature scaling (StandardScaler / MinMaxScaler)
#
# ---
#
# ## 📈 Exploratory Data Analysis (EDA)
# - 📌 Univariate & Bivariate analysis
# - 🧠 Correlation analysis
# - 🎯 Distribution of target variable (Health status)
#
# ---
#
# ## 🤖 Machine Learning Models Used
#
# ### ✅ Logistic Regression
# Simple linear model for binary classification problems.
#
# ### 🌲 Random Forest Classifier
# Ensemble technique using multiple decision trees.
#
# ### 🧠 Decision Tree Classifier
# Flowchart-like tree structure for classification tasks.
#
# ### 📚 K-Nearest Neighbors (KNN)
# Predicts the class based on nearest data points.
#
# ### 📐 Support Vector Machine (SVM)
# Draws optimal hyperplane to classify the data.

# %% [markdown]
# ## import Neceaasry Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("/kaggle/input/impact-of-sleep-on-health-lifestyle/Sleep_health_and_lifestyle_dataset.csv")

# %% [markdown]
# ## Show Dataset

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ## Information About the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.sample(10)
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 46          47    Male   31       Doctor             7.7                 7
# 369        370  Female   59        Nurse             8.1                 9
# 153        154    Male   39       Lawyer             7.2                 8
# 9           10    Male   29       Doctor             7.8                 7
# 137        138    Male   38       Lawyer             7.1                 8
# 356        357  Female   58        Nurse             8.0                 9
# 210        211    Male   43     Engineer             7.7                 8
# 295        296  Female   50        Nurse             6.0                 6
# 178        179    Male   42       Lawyer             7.8                 8
# 231        232    Male   44  Salesperson             6.3                 6
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %% [markdown]
# ## Treat The Missing Value

# %%
df = df.dropna(subset=['Sleep Disorder'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                155 non-null    int64
#  1   Gender                   155 non-null    object
#  2   Age                      155 non-null    int64
#  3   Occupation               155 non-null    object
#  4   Sleep Duration           155 non-null    float64
#  5   Quality of Sleep         155 non-null    int64
#  6   Physical Activity Level  155 non-null    int64
#  7   Stress Level             155 non-null    int64
#  8   BMI Category             155 non-null    object
#  9   Blood Pressure           155 non-null    object
#  10  Heart Rate               155 non-null    int64
#  11  Daily Steps              155 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 17.0+ KB

# %%
df['Occupation'].unique()
# Out:
# array(['Sales Representative', 'Software Engineer', 'Teacher', 'Nurse',
#        'Doctor', 'Scientist', 'Lawyer', 'Accountant', 'Engineer',
#        'Salesperson'], dtype=object)

# %%
df['Occupation'].nunique()
# Out:
# 10

# %%
df['BMI Category'].unique()
# Out:
# array(['Obese', 'Normal Weight', 'Normal', 'Overweight'], dtype=object)

# %%
df['Blood Pressure'].unique()
# Out:
# array(['140/90', '132/87', '120/80', '130/86', '125/80', '131/86',
#        '135/88', '115/75', '129/84', '130/85', '135/90', '142/92',
#        '140/95', '139/91'], dtype=object)

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df['Physical Activity Level'].unique()
# Out:
# array([30, 40, 35, 75, 32, 60, 90, 45, 65, 85])

# %% [markdown]
# ## EDA(Exploratory Data Analysis)

# %% [markdown]
# ### Distribution among Numerical columns

# %%
df_numeric = df.select_dtypes(include = 'number')
for col in df_numeric:
    sns.histplot(df[col],kde = True)
    plt.title("correlation between numerical features")
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ### Correalation Between the Numerical Columns

# %%
correlation_matrix = df_numeric.corr()

plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation matrix Numerical vs Numerical")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                155 non-null    int64
#  1   Gender                   155 non-null    object
#  2   Age                      155 non-null    int64
#  3   Occupation               155 non-null    object
#  4   Sleep Duration           155 non-null    float64
#  5   Quality of Sleep         155 non-null    int64
#  6   Physical Activity Level  155 non-null    int64
#  7   Stress Level             155 non-null    int64
#  8   BMI Category             155 non-null    object
#  9   Blood Pressure           155 non-null    object
#  10  Heart Rate               155 non-null    int64
#  11  Daily Steps              155 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 17.0+ KB

# %% [markdown]
# ### Distributtion of Ctegorical vs Categorical Columns

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender', hue='Sleep Disorder', data=df)

plt.title('Relationship between Sleep Order and gender')
plt.xlabel('gender')
plt.ylabel('Sleep Disorder')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender', hue='Blood Pressure', data=df)

plt.title('Relationship between Blood Pressure and gender')
plt.xlabel('gender')
plt.ylabel('Blood Pressure')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Gender', y='Physical Activity Level', data=df, ci=None)
plt.title('Physical activity level through gender')
plt.xlabel('Gender')
plt.ylabel('Physical Activity Level')
plt.show()
# Out:
# /tmp/ipykernel_35/195473136.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Gender', y='Physical Activity Level', data=df, ci=None)

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Gender', y='Sleep Duration', data=df, ci=None)
plt.title('Sleep Duration through gender')
plt.xlabel('Gender')
plt.ylabel('Sleep Duration')
plt.show()
# Out:
# /tmp/ipykernel_35/476555827.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Gender', y='Sleep Duration', data=df, ci=None)

# %% [markdown]
# ## Import Necessery Algorithms

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import category_encoders 
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Remove first Column

# %%
df = df.drop('Person ID', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   155 non-null    object
#  1   Age                      155 non-null    int64
#  2   Occupation               155 non-null    object
#  3   Sleep Duration           155 non-null    float64
#  4   Quality of Sleep         155 non-null    int64
#  5   Physical Activity Level  155 non-null    int64
#  6   Stress Level             155 non-null    int64
#  7   BMI Category             155 non-null    object
#  8   Blood Pressure           155 non-null    object
#  9   Heart Rate               155 non-null    int64
#  10  Daily Steps              155 non-null    int64
#  11  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 15.7+ KB

# %% [markdown]
# ## Separate the Independent columns and dependent columns

# %%
X = df.iloc[:,0:11]
y = df.iloc[:,-1]

# %% [markdown]
# ### Encode the Target Variable

# %%
label = LabelEncoder()
encoded_y = label.fit_transform(y)

# %% [markdown]
# ## Separate the Dataset Into Training and Testing Dataset

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1,random_state =42)

# %%
X_train
# Out:
#      Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 190  Female   43      Teacher             6.7                 7
# 271  Female   49        Nurse             6.1                 6
# 305  Female   51        Nurse             6.1                 6
# 354  Female   58        Nurse             8.0                 9
# 144    Male   38       Lawyer             7.1                 8
# ..      ...  ...          ...             ...               ...
# 246    Male   44  Salesperson             6.3                 6
# 289  Female   50        Nurse             6.1                 6
# 94   Female   36   Accountant             7.2                 8
# 273  Female   49        Nurse             6.2                 6
# 285  Female   50        Nurse             6.0                 6
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 190                       45             4   Overweight         135/90
# ...

# %%
y_train
# Out:
# 190       Insomnia
# 271    Sleep Apnea
# 305    Sleep Apnea
# 354    Sleep Apnea
# 144    Sleep Apnea
#           ...
# 246       Insomnia
# 289    Sleep Apnea
# 94        Insomnia
# 273    Sleep Apnea
# 285    Sleep Apnea
# Name: Sleep Disorder, Length: 139, dtype: object

# %%
y_test
# Out:
# 258       Insomnia
# 361    Sleep Apnea
# 191       Insomnia
# 189       Insomnia
# 306       Insomnia
# 235       Insomnia
# 274    Sleep Apnea
# 366    Sleep Apnea
# 372    Sleep Apnea
# 243       Insomnia
# 202       Insomnia
# 355    Sleep Apnea
# 255       Insomnia
# 252       Insomnia
# 103    Sleep Apnea
# 145    Sleep Apnea
# Name: Sleep Disorder, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155 entries, 3 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   155 non-null    object
#  1   Age                      155 non-null    int64
#  2   Occupation               155 non-null    object
#  3   Sleep Duration           155 non-null    float64
#  4   Quality of Sleep         155 non-null    int64
#  5   Physical Activity Level  155 non-null    int64
#  6   Stress Level             155 non-null    int64
#  7   BMI Category             155 non-null    object
#  8   Blood Pressure           155 non-null    object
#  9   Heart Rate               155 non-null    int64
#  10  Daily Steps              155 non-null    int64
#  11  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 15.7+ KB

# %% [markdown]
# ## Encode the Variable Using Column Transformer

# %%
numeric_cols = ['Age','Sleep Duration','Quality of Sleep','Physical Activity Level','Stress Level','Heart Rate',
               'Daily Steps']
categoric_cols = ['Gender','Occupation']
ordinal_cols = ['BMI Category','Blood Pressure']

# %%
categories = ['Normal','Normal Weight','Overweight','Obese']
bp_categories = [
    '115/75',
    '120/80',
    '125/80',
    '129/84',
    '130/85',
    '130/86',
    '131/86',
    '132/87',
    '135/88',
    '135/90',
    '139/91',
    '140/90',
    '140/95',
    '142/92'
]

# %%
one = OneHotEncoder(handle_unknown='ignore',drop='first')
ordinal =OrdinalEncoder(categories = [categories,bp_categories]) 
scaler = StandardScaler()

# %% [markdown]
# ## Use ColumnTransformer For applying Transformation in Each Column

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('one_hot',one,categoric_cols),
        ('ordinal',ordinal,ordinal_cols),
        ('scaling',scaler,numeric_cols)
    ]
)

# %%
lr = LogisticRegression()
dt = DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=None)
rf = RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=None)
svc = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', shrinking=True, probability=False)

# %% [markdown]
# ## Use Pipeline for Fit the model

# %%
pipeline = Pipeline([
    ('preprocessor',preprocessor),
    ('lr',lr)
])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Gender', 'Occupation']),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories=[['Normal',
#                                                                               'Normal '
#                                                                               'Weight',
#                                                                               'Overweight',
#                                                                               'Obese'],
#                                                                              ['115/75',
# ...

# %%
y_pred =  pipeline.predict(X_test)

# %% [markdown]
# # Check Accuracy for each Algorithms and Choose the best model

# %%
from sklearn.metrics import classification_report,accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.875

# %% [markdown]
# ### For the Logistic Regression

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n    Insomnia       0.89      0.89      0.89         9\n Sleep Apnea       0.86      0.86      0.86         7\n\n    accuracy                           0.88        16\n   macro avg       0.87      0.87      0.87        16\nweighted avg       0.88      0.88      0.88        16\n'

# %%
y_pred_train = pipeline.predict(X_train)

# %%
from sklearn.metrics import classification_report,accuracy_score

accuracy_score(y_train,y_pred_train)
# Out:
# 0.9064748201438849

# %%
classification_report(y_train,y_pred_train)
# Out:
# '              precision    recall  f1-score   support\n\n    Insomnia       0.91      0.90      0.90        68\n Sleep Apnea       0.90      0.92      0.91        71\n\n    accuracy                           0.91       139\n   macro avg       0.91      0.91      0.91       139\nweighted avg       0.91      0.91      0.91       139\n'

# %% [markdown]
# ### For the Decision Tree

# %%
pipeline2 = Pipeline([
    ('preprocessor',preprocessor),
    ('dt',dt)
])

# %%
pipeline2.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Gender', 'Occupation']),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories=[['Normal',
#                                                                               'Normal '
#                                                                               'Weight',
#                                                                               'Overweight',
#                                                                               'Obese'],
#                                                                              ['115/75',
# ...

# %%
y_pred2 =  pipeline2.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9375

# %%
classification_report(y_test,y_pred2)
# Out:
# '              precision    recall  f1-score   support\n\n    Insomnia       0.90      1.00      0.95         9\n Sleep Apnea       1.00      0.86      0.92         7\n\n    accuracy                           0.94        16\n   macro avg       0.95      0.93      0.94        16\nweighted avg       0.94      0.94      0.94        16\n'

# %%
y_pred_train1 = pipeline2.predict(X_train)

# %%
accuracy_score(y_train,y_pred_train1)
# Out:
# 0.9640287769784173

# %% [markdown]
# ### For RandomForest

# %%
pipeline3 = Pipeline([
    ('preprocessor',preprocessor),
    ('rf',rf)
])

# %%
pipeline3.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Gender', 'Occupation']),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories=[['Normal',
#                                                                               'Normal '
#                                                                               'Weight',
#                                                                               'Overweight',
#                                                                               'Obese'],
#                                                                              ['115/75',
# ...

# %%
y_pred3 =  pipeline3.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9375

# %% [markdown]
# ### For SVM Classiefier

# %%
pipeline4 = Pipeline([
    ('preprocessor',preprocessor),
    ('svc',svc)
])

# %%
pipeline4.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('one_hot',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['Gender', 'Occupation']),
#                                                  ('ordinal',
#                                                   OrdinalEncoder(categories=[['Normal',
#                                                                               'Normal '
#                                                                               'Weight',
#                                                                               'Overweight',
#                                                                               'Obese'],
#                                                                              ['115/75',
# ...

# %%
y_pred4 = pipeline4.predict(X_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.9375
